# %% [markdown]
# # Final Project Notebook
#
# DS 5001 Exploratory Text Analytics | Spring 2024

# %% [markdown]
# # Metadata
#
# - Full Name: Ian Yung
# - Userid: icy4r
# - GitHub Repo URL: https://github.com/Icy4r/DS5001-proj
# - UVA Box URL: https://virginia.box.com/s/paz0j87omuq6fx2xyis9hhwck948ewrs

# %% [markdown]
# # Overview
#
# The goal of the final project is for you to create a **digital analytical edition** of a corpus using the tools, practices, and perspectives you’ve learning in this course. You will select a corpus that has already been digitized and transcribed, parse that into an F-compliant set of tables, and then generate and visualize the results of a series of fitted models. You will also draw some tentative conclusions regarding the linguistic, cultural, psychological, or historical features represented by your corpus. The point of the exercise is to have you work with a corpus through the entire pipeline from ingestion to interpretation.
#
# Specifically, you will acquire a collection of long-form texts and perform the following operations:
#
# - **Convert** the collection from their source formats (F0) into a set of tables that conform to the Standard Text Analytic Data Model (F2).
# - **Annotate** these tables with statistical and linguistic features using NLP libraries such as NLTK (F3).
# - **Produce** a vector representation of the corpus to generate TFIDF values to add to the TOKEN (aka CORPUS) and VOCAB tables (F4).
# - **Model** the annotated and vectorized model with tables and features derived from the application of unsupervised methods, including PCA, LDA, and word2vec (F5).
# - **Explore** your results using statistical and visual methods.
# - **Present** conclusions about patterns observed in the corpus by means of these operations.
#
# When you are finished, you will make the results of your work available in GitHub (for code) and UVA Box (for data). You will submit to Gradescope (via Canvas) a PDF version of a Jupyter notebook that contains the information listed below.
#
# # Some Details
#
# - Please fill out your answers in each task below by editing the markdown cell.
# - Replace text that asks you to insert something with the thing, i.e. replace `(INSERT IMAGE HERE)` with an image element, e.g. `![](image.png)`.
# - For URLs, just paste the raw URL directly into the text area. Don't worry about providing link labels using `[label](link)`.
# - Please do not alter the structure of the document or cell, i.e. the bulleted lists.
# - You may add explanatory paragraphs below the bulleted lists.
# - Please name your tables as they are named in each task below.
# - Tasks are indicated by headers with point values in parentheses.

# %% [markdown]
# # Raw Data

# %% [markdown]
# ## Source Description (1)

# %% [markdown]
# Provide a brief description of your source material, including its provenance and content. Tell us where you found it and what kind of content it contains.
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# *The Complete Works of J.R.R. Tolkien* is a collection of the life and work of John Ronald Reuel Tolkien, the famous linguist and author of the "Lord of the Rings" series. The archive was developed through the Internet Archive, a nonprofit organization devoted to the archival and documentation "of cultural artifacts in digital form" (Archive). It contains the entire Lord of the Rings series, the Hobbit, The Silmarillion, and the Book of Lost Tales. Other works were contained within the archive (a collection of Tolkien's letters, for instance), but for the sake of this project, these were the works utilized for analysis.
#
# *The Chronicles of Narnia* also was added to the CORPUS, and it was also pulled from the Internet Archive. This series is probably C.S. Lewis's most famous works, and they depict a group of children escaping from Blitz-era London to a fantasy land called Narnia.

# %% [markdown]
# ## Source Features (1)
#
# Add values for the following items. (Do this for all following bulleted lists.)
#
# - Source URL: https://archive.org/details/the-complete-works-of-j.-r.-r-tolkien, https://archive.org/details/LewisCSNarnia3TheHorseAndHisBoy/Lewis_C_S_-_Narnia_1_-_The_Magician_s_Nephew/
# - UVA Box URL: https://virginia.box.com/s/825scdaegdarz85rlv982dxniajkoxhc, https://virginia.box.com/s/hvu0ok2v9dsrm7ge83l3xvycpx0009lh
# - Number of raw documents: 17
# - Total size of raw documents (e.g. in MB): 349 MB
# - File format(s), e.g. XML, plaintext, etc.: EPUB

# %% [markdown]
# ## Source Document Structure (1)
#
# Provide a brief description of the internal structure of each document. That, describe the typical elements found in document and their relation to each other. For example, a corpus of letters might be described as having a date, an addressee, a salutation, a set of content paragraphs, and closing. If they are various structures, state that.
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# Most documents contained within the set follow the traditional structure of novels; they follow a book, chapter, paragraph, sentence,  word structure. The *Lord of the Rings* books are peculiar in that they each technically contain two books within each file (*The Fellowship of the Ring*, for instance, is actually technically two books). This was resolved by treating them as one singular unit - I simply treated the series as a trilogy, with three different books rather than six.

# %% [markdown]
# # Parsed and Annotated Data
#
# Parse the raw data into the three core tables of your addition: the `LIB`, `CORPUS`, and `VOCAB` tables.
#
# These tables will be stored as CSV files with header rows.
#
# You may consider using `|` as a delimitter.
#
# Provide the following information for each.

# %% [markdown]
# ## LIB (2)
#
# The source documents the corpus comprises. These may be books, plays, newspaper articles, abstracts, blog posts, etc.
#
# Note that these are *not* documents in the sense used to describe a bag-of-words representation of a text, e.g. chapter.
#
# - UVA Box URL: https://virginia.box.com/s/mtr1ge8dowvw95cux89svhrdjauu6wwx
# - GitHub URL for notebook used to create: https://github.com/Icy4r/DS5001-proj/blob/main/project-parsing.ipynb
# - Delimitter: ,
# - Number of observations: 14
# - List of features, including at least three that may be used for model summarization (e.g. date, author, etc.): date, author, book length
# - Average length of each document in characters:

# %% [markdown]
# ## CORPUS (2)
#
# The sequence of word tokens in the corpus, indexed by their location in the corpus and document structures.
#
# - UVA Box URL: https://virginia.box.com/s/chcrfeyu0bwsxbb3jbjrzkj3ypbk3pqs
# - GitHub URL for notebook used to create:  https://github.com/Icy4r/DS5001-proj/blob/main/project-parsing.ipynb
# - Delimitter: ,
# - Number of observations Between (should be >= 500,000 and <= 2,000,000 observations.): 1,278,935 observations
# - OHCO Structure (as delimitted column names): OHCO = `book_id`, `chap_num`, `para_num`, `sent_num`, `token_num`
# - Columns (as delimitted column names, including `token_str`, `term_str`, `pos`, and `pos_group`): `pos_tuple`

# %% [markdown]
# ## VOCAB (2)
#
# The unique word types (terms) in the corpus.
#
# - UVA Box URL: https://virginia.box.com/s/ypjm9ln08zkf6bvzn7zz53kwwc9kz4o2
# - GitHub URL for notebook used to create: https://github.com/Icy4r/DS5001-proj/blob/main/project-parsing.ipynb
# - Delimitter: ,
# - Number of observations: 23,595 observations
# - Columns (as delimitted names, including `n`, `p`', `i`, `dfidf`, `porter_stem`, `max_pos` and `max_pos_group`, `stop`):
# - Note: Your VOCAB may contain ngrams. If so, add a feature for `ngram_length`.
# - List the top 20 significant words in the corpus by DFIDF.
#
# asleep\
# belt\
# shire\
# prepared\
# busy\
# mortal\
# willing\
# burst\
# setting\
# story\
# window\
# listened\
# bottom\
# especially\
# sweet\
# sank\
# shouted\
# understood\
# knowledge\
# delight

# %% [markdown]
# # Derived Tables

# %% [markdown]
# ## BOW (3)
#
# A bag-of-words representation of the CORPUS.
#
# - UVA Box URL: https://virginia.box.com/s/3j8wmstjowqwfocgshhydx5bs5flyypo
# - GitHub URL for notebook used to create: https://github.com/Icy4r/DS5001-proj/blob/main/project-tables.ipynb
# - Delimitter: ,
# - Bag (expressed in terms of OHCO levels): CHAP = ['book_id', 'chap_num']
# - Number of observations: 178,219 observations
# - Columns (as delimitted names, including `n`, `tfidf`): ['n', 'tfidf']

# %% [markdown]
# ## DTM (3)
#
# A represenation of the BOW as a sparse count matrix.
#
# - UVA Box URL: https://virginia.box.com/s/td7066tdgroyzhdcxlg91dahd7l8364j
# - UVA Box URL of BOW used to generate (if applicable): https://virginia.box.com/s/3j8wmstjowqwfocgshhydx5bs5flyypo
# - GitHub URL for notebook used to create: https://github.com/Icy4r/DS5001-proj/blob/main/project-tables.ipynb
# - Delimitter: ,
# - Bag (expressed in terms of OHCO levels): ['book_id', 'chap_num']

# %% [markdown]
# ## TFIDF (3)
#
# A Document-Term matrix with TFIDF values.
#
# - UVA Box URL: https://virginia.box.com/s/0e3i01ev4et4xv0w9pnwfvp43uw9hj3d
# - UVA Box URL of DTM or BOW used to create: https://virginia.box.com/s/3j8wmstjowqwfocgshhydx5bs5flyypo
# - GitHub URL for notebook used to create: https://github.com/Icy4r/DS5001-proj/blob/main/project-tables.ipynb
# - Delimitter: ,
# - Description of TFIDIF formula ($\LaTeX$ OK): $\text{TF-IDF}(t, d) = \text{TF}(t, d) \times \text{IDF}(t)$, where TF is calculated using 'max' ($TF = \left( \frac{{DTCM^T}}{{DTCM^T.\text{max}()}} \right)^T$) and IDF is calculated using the standard log function ($IDF = \log_2\left(\frac{N_{\text{docs}}}{\text{DF}}\right)$).

# %% [markdown]
# ## Reduced and Normalized TFIDF_L2 (3)

# %% [markdown]
# A Document-Term matrix with L2 normalized TFIDF values.
#
# - UVA Box URL: https://virginia.box.com/s/1eydalouph5tzyujewf0ovcjep8m61db
# - UVA Box URL of source TFIDF table: https://virginia.box.com/s/0e3i01ev4et4xv0w9pnwfvp43uw9hj3d
# - GitHub URL for notebook used to create: https://github.com/Icy4r/DS5001-proj/blob/main/project-tables.ipynb
# - Delimitter: ,
# - Number of features (i.e. significant words): Reduced to 4000 most-significant words.
# - Principle of significant word selection: words that appear most frequently

# %% [markdown]
# # Models

# %% [markdown]
# ## PCA Components (4)
#
# - UVA Box URL: https://virginia.box.com/s/0bktymgxn555mnjovny07cmdtc05j0on
# - UVA Box URL of the source TFIDF_L2 table: https://virginia.box.com/s/1eydalouph5tzyujewf0ovcjep8m61db
# - GitHub URL for notebook used to create: https://github.com/Icy4r/DS5001-proj/blob/main/project-models.ipynb
# - Delimitter: ,
# - Number of components: 10
# - Library used to generate: numpy.linalg (eig)
# - Top 5 positive terms for first component: 'p', 'text', 'thou', 'pp', 'tale'
# - Top 5 negative terms for second component: 'hobbits', 'dont', 'ponies', 'goblins', 'ents'

# %% [markdown]
# ## PCA DCM (4)
#
# The document-component matrix generated.
#
# - UVA Box URL: https://virginia.box.com/s/5wdardsc40ciw037sts4zduksrtl2s7x
# - GitHub URL for notebook used to create: https://github.com/Icy4r/DS5001-proj/blob/main/project-models.ipynb
# - Delimitter: ,

# %% [markdown]
# ## PCA Loadings (4)
#
# The component-term matrix generated.
#
# - UVA Box URL: https://virginia.box.com/s/yyogdzf4s25we9pnvzy8ms8vf3jdt7bt
# - GitHub URL for notebook used to create: https://github.com/Icy4r/DS5001-proj/blob/main/project-models.ipynb
# - Delimitter: ,

# %%
# For visualization purposes
from IPython.display import Image
from IPython.core.display import HTML 
PATH = "graphs/"

# %% [markdown]
# ## PCA Visualization 1 (4)
#
# Include a scatterplot of documents in the space created by the first two components.
#
# Color the points based on a metadata feature associated with the documents.
#
# Also include a scatterplot of the loadings for the same two components. (This does not need a feature mapped onto color.)

# %%
Image(filename = PATH + "graph1.png")

# %%
Image(filename = PATH + "graph2.png")

# %% [markdown]
# Briefly describe the nature of the polarity you see in the first component:
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# Horses, ponies, hoofs, giants, miles, hobbits, seem to score highly on PC0 while elves, tale, text, name, seas, and dwelling score highly on PC1. It appears that PC0 is dealing with animals and creatures, while PC0 somewhat deals with natural elements and adventure.

# %% [markdown]
# ## PCA Visualization 2 (4)
#
# Include a scatterplot of documents in the space created by the second two components.
#
# Color the points based on a metadata feature associated with the documents.
#
# Also include a scatterplot of the loadings for the same two components. (This does not need a feature mapped onto color.)

# %%
Image(filename = PATH + "graph3.png")

# %%
Image(filename = PATH + "graph4.png")

# %% [markdown]
# Briefly describe the nature of the polarity you see in the second component:
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# There are so many words that it is relatively hard to interpret the graph. That said, looking closer into the PCA visualization, we can see that 'cities', 'ships', and 'towns' appears quite a bit on one side whereas 'forest', 'seas' and 'woods' appears on the other. This seems to suggest that there may be a difference between the two authors in the settings of their stories - Tolkien's stories perhaps being set in more civilized land contrary to Lewis whose stories focus on nature (Tolkien's stories also focusing on nature, but his work is often a critique of the harmful impacts of humans on nature, hence the environment being that of cities in Tolkien's works).

# %% [markdown]
# ## LDA TOPIC (4)
#
# - UVA Box URL: https://virginia.box.com/s/xkf61sci4h8tvu7xz2tbs0gy5601htw2
# - UVA Box URL of count matrix used to create:
# - GitHub URL for notebook used to create: https://github.com/Icy4r/DS5001-proj/blob/main/project-models.ipynb
# - Delimitter: ,
# - Libary used to compute: CountVectorizer and LDA_engine
# - A description of any filtering, e.g. POS (Nouns and Verbs only): POS
# - Number of components:  40
# - Any other parameters used:
# - Top 5 words and best-guess labels for topic five topics by mean document weight:
#   - T00: way night time trees water
#   - T01: elves son people time earth
#   - T02: time hobbits way things night
#   - T03: way eyes head road hobbits
#   - T04: hand eyes things thing time

# %% [markdown]
# ## LDA THETA (4)
#
# - UVA Box URL: https://virginia.box.com/s/1g07vj3b1c2aezd0lfj6d08no0nme3ey
# - GitHub URL for notebook used to create: https://github.com/Icy4r/DS5001-proj/blob/main/project-models.ipynb
# - Delimitter: ,

# %% [markdown]
# ## LDA PHI (4)
#
# - UVA Box URL: https://virginia.box.com/s/ctbb6u37e4rqhnh3app44utz5yt0nqzz
# - GitHub URL for notebook used to create: https://github.com/Icy4r/DS5001-proj/blob/main/project-models.ipynb
# - Delimitter: ,

# %% [markdown]
# ## LDA + PCA Visualization (4)
#
# Apply PCA to the PHI table and plot the topics in the space opened by the first two components.
#
# Size the points based on the mean document weight of each topic (using the THETA table).
#
# Color the points basd on a metadata feature from the LIB table.

# %%
Image(filename = PATH + "graph5.png")

# %%
Image(filename = PATH + "graph6.png")

# %% [markdown]
# Provide a brief interpretation of what you see.
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# Words like "kings", "battle", "sword", and "power" all seemed to cluster together, suggesting that power is intricately connected with that of violence and bloodshed within these stories. This makes sense - the *Lord of the Rings* trilogy is an explicit critique on power and the drastically harmful consequences of pursuing it entails, so it makes sense for these words to go together.

# %% [markdown]
# ## Sentiment VOCAB_SENT (4)
#
# Sentiment values associated with a subset of the VOCAB from a curated sentiment lexicon.
#
# - UVA Box URL: https://virginia.box.com/s/rbjeozpvjldepzog71v7o8ecr2meduk7
# - UVA Box URL for source lexicon: https://virginia.box.com/s/rxyv99c8lpkndf62fks3jawclsle4t6g
# - GitHub URL for notebook used to create: https://github.com/Icy4r/DS5001-proj/blob/main/project-models.ipynb
# - Delimitter: ,

# %% [markdown]
# ## Sentiment BOW_SENT (4)
#
# Sentiment values from VOCAB_SENT mapped onto BOW.
#
# - UVA Box URL: https://virginia.box.com/s/luh364dypoo4shjm8yaob4wurimta1eg
# - GitHub URL for notebook used to create: https://github.com/Icy4r/DS5001-proj/blob/main/project-models.ipynb
# - Delimitter: ,

# %% [markdown]
# ## Sentiment DOC_SENT (4)
#
# Computed sentiment per bag computed from BOW_SENT.
#
# - UVA Box URL: https://virginia.box.com/s/wmh5ikbbit8sulrl400hxmnshqphh0mf
# - GitHub URL for notebook used to create: https://github.com/Icy4r/DS5001-proj/blob/main/project-models.ipynb
# - Delimitter: ,
# - Document bag expressed in terms of OHCO levels: ['book_id', 'chap_num']

# %% [markdown]
# ## Sentiment Plot (4)
#
# Plot sentiment over some metric space, such as time.
#
# If you don't have a metric metadata features, plot sentiment over a feature of your choice.
#
# You may use a bar chart or a line graph.

# %%
Image(filename = PATH + "graph7.png")

# %%
Image(filename = PATH + "graph8.png")

# %% [markdown]
# ## VOCAB_W2V (4)
#
# A table of word2vec features associated with terms in the VOCAB table.
#
# - UVA Box URL: https://virginia.box.com/s/sf8qhx9tnpza718n7rffbzceih7kspt2
# - GitHub URL for notebook used to create: https://github.com/Icy4r/DS5001-proj/blob/main/project-models.ipynb
# - Delimitter: ,
# - Document bag expressed in terms of OHCO levels:
# - Number of features generated: 200
# - The library used to generate the embeddings: Word2Vec

# %% [markdown]
# ## Word2vec tSNE Plot (4)
#
# Plot word embedding featues in two-dimensions using t-SNE.
#
# Describe a cluster in the plot that captures your attention.

# %%
Image(filename = PATH + "graph13.png")

# %% [markdown]
# "Desperate", "madness", "pain", and "deadly" are all clustered together, which I think is interesting. It suggests that death and pain are closely intertwined with madness; that a brain not functioning properly leads to suffering for everyone involved.

# %% [markdown]
# # Riffs
#
# Provde at least three visualizations that combine the preceding model data in interesting ways.
#
# These should provide insight into how features in the LIB table are related.
#
# The nature of this relationship is left open to you -- it may be correlation, or mutual information, or something less well defined.
#
# In doing so, consider the following visualization types:
#
# - Hierarchical cluster diagrams
# - Heatmaps
# - Scatter plots
# - KDE plots
# - Dispersion plots
# - t-SNE plots
# - etc.

# %% [markdown]
# ## Riff 1 (5)

# %%
Image(filename = PATH + "graph10.png")

# %% [markdown]
# It seems apparent that "love" appears more frequently in Tolkien's books, but they have higher TFIDF-importance in Lewis's novels. Both authors were devout Christians - this may be relevant to better understanding why this may be.

# %% [markdown]
# ## Riff 2 (5)

# %%
Image(filename = PATH + "graph12.png")

# %% [markdown]
# The correlation between the novels follows exactly what one would expect. The works of Lewis all correlate strongly with one another (book_id 8-14), and other points of similarity include: the *Lord of the Rings* trilogy, in the first three cubes, all correlate strongly with one another, and books 5 and 6 (which form parts 1 and 2 of the Lost Tales) correlate strongly, Any books that are part of a series correlate strongly with other books within that series, which is what we would expect.

# %% [markdown]
# ## Riff 3 (5)

# %% [markdown]
# ### Topic Modeling by Author

# %%
Image(filename = PATH + "graph11.png")

# %% [markdown]
# It almost seems as though Tolkien's stories deal with power, kings, war, and battle, whereas Lewis's stories seem to have a more down-to-earth focus on small, seemingly trivial objects like doors, wardrobes, trees, snow, people. This is interesting, because while both stories are written from a Christian perspective, Tolkien's stories seem like they are explicitly making some kind of statement about power, whereas Lewis seems to be making a statement about life, nature, and existence in general.

# %% [markdown]
# # Interpretation (4)
#
# Describe something interesting about your corpus that you discovered during the process of completing this assignment.
#
# At a minumum, use 250 words, but you may use more. You may also add images if you'd like.
#
# ---------------------------------------------------------------------------------------------------------------------------------------
#
# My interpretation of the project is that the authors had different approaches to what they wanted to focus on, despite both coming from very religious backgrounds and both telling, essentially, religious parables in their stories. It's fascinating to me, from the above topic modeling of the authors, that Tolkien seemed much more focused on power and violence, kingship and politics, contrasted with Lewis who focused heavily on nature, trees, witches, and the beautiful (and sometimes hideous) monotony of everyday life. Both authors were writing in the post-war period, and both had witnessed horrific atrocities in their lives - while Lewis seems to focus on escapism into a mystical land (through the wardrobe into a beautiful, natural world; far away from the atrocities of Blitz-era London), Tolkien does not provide escapism at all. The world of Middle Earth is just as brutal, hideous, and grotesque as that of reality, at least from words like "power", "violence", and "destruction" that appear frequently and prominently in Tolkien's corpora.
#
# I think it's important that, although both authors wrote stories containing different elements of fantasy, they still treated these fantasy elements in the same way. That is, words like "dragons", "elves", "hobbits", "men", "witches", "lions", and "magicians" all appeared clustered together throughout any of the visualizations above. It seems that, although these are objects of fantasy, they are all given deeply human characteristics, which allows them to be mostly treated more-or-less in the same manner. So while Tolkien and Lewis both wrote very different stories, they were fundamentally both writing about humanity, which is has universally applicable themes.
